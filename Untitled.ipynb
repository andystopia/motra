# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from motra import MotraModel

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 18})
plt.style.use('ggplot')

# %%
model = MotraModel.read_csv("2022-06-10_1_UL.water-vapor.csv")

# %%
model

# %%
model.data
# Out:
#         fly id  pos x  pos y    timestamp
# 0            1  372.0  379.0     0.000000
# 1            1  372.0  376.0     0.033333
# 2            1  374.0  373.0     0.066667
# 3            1  373.0  372.0     0.100000
# 4            1  373.0  369.0     0.133333
# ...        ...    ...    ...          ...
# 105124       3  142.0  134.0  1167.933333
# 105125       3  142.0  133.0  1167.966667
# 105126       3  142.0  134.0  1168.000000
# 105127       3  143.0  134.0  1168.033333
# 105128       3  142.0  135.0  1168.066667
#
# [105129 rows x 4 columns]

# %%
model.plot_distance_from_center_histogram()
# Out:
# <AxesSubplot:>

# %%
help(model.plot_smooth_velocity)
# Out:
# Help on method plot_smooth_velocity in module motra.motra_model:
#
# plot_smooth_velocity(smoothing=1, axis=None, size: 'tuple[int, int] | int' = 14, apply_legend=False) method of motra.motra_model.MotraModel instance
#     Plots the smoothed velocity over time
#     Parameters
#     ----------
#     smoothing: the unit in seconds to plot the smoothed velocity over.
#     axis: the axis to plot on, if none, one will be generated.
#     size: the size of the axis to plot onto, if generated.
#     apply_legend: whether or not to apply a legened
#
#     Returns
#     -------
#     the axis plotted on.

# %% [markdown]
# model.plot_smooth_velocity(20)

# %%
model.plot_smooth_velocity(30)
# Out:
# <AxesSubplot:>
