# %%
# %load_ext autoreload
# %autoreload 2

# %%
from motra import MotraModel

# %%
model = MotraModel.read_csv("assets/2022-06-06_UL.water-vapor_wild-type-vF_LR2.water-vapor_wild-type_vM copy.csv")

# %%
model.plot()
# Out:
# <AxesSubplot:>

# %%
help(model.overlay_quadrants)
# Out:
# Help on method overlay_quadrants in module motra.motra_model:
#
# overlay_quadrants(splitting_origin_point: 'Coordinate | tuple', *, include_top_left=True, include_top_right=True, include_bottom_left=True, include_bottom_right=True) -> "'MotraModel'" method of motra.motra_model.MotraModel instance
#     Splits the quadrants up and then centers them, scales them to the
#     arena size.
#     Parameters
#     ----------
#     splitting_origin_point: the point at which to split the dataset at.
#     include_top_left: whether to include the top left quadrant
#     include_top_right: whether to include the top right quadrant
#     include_bottom_left: whether to include the bottom left quadrant
#     include_bottom_right: whether to include the bottom right quadrant
#
#     Returns
#     -------
#     a new motra model with the quadrants overlaid.

# %%
quads = model.overlay_quadrants((0, 325), include_top_left=False, include_bottom_left=False)
# Out:
# [<motra.motra_model.MotraModel object at 0x7f9bb0cbb490>
#  <motra.motra_model.MotraModel object at 0x7f9bb0cbb460>]

# %%
quads.plot()
# Out:
# <AxesSubplot:>

# %%
quads.get_fly_identifiers()
# Out:
# [1, 2, 3, 4]

# %%
axis = quads.plot_distance_from_center_histogram(size=14)
axis.set_ylabel("Occurences in paths")
axis.set_xlabel("Distance from center")
axis.set_title("Water Vapor Distance Histogram");

# %%
axis = quads.plot_distance_from_center_over_time()
axis.set_title("Distance From Center vs time")
axis.set_ylabel("Distance from the center (mm)")
axis.set_xlabel("time in seconds")
# Out:
# Text(0.5, 0, 'time in seconds')
