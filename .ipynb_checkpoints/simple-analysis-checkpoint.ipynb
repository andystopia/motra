# %% [markdown]
# # Fly Example Parse Proof of Concept
#
# The idea of this project is a proof of concept fly parsing model, so that we can see the parsing model at work.

# %% [markdown]
# First, let's start out with adding motra to our path, where we don't have it installed as a module.

# %%
import sys
sys.path.append("/Users/andy/Documents/colby/summer-2022/data-analysis/motra")
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Now, let's pull in our motra library and
# our standard data science include, matplotlib.

# %%
import motra
from motra import MotraModel
import matplotlib.pyplot as plt

# %% [markdown]
# Now let's read in a single tracking file

# %%
simple_model = MotraModel.read_csv("/Users/andy/Documents/colby/summer-2022/data-analysis/motra/assets/tracks.csv")

# %%
ax = simple_model.plot(size=12)
ax.set_title("Fly paths in all wells")
ax.set_xlabel("World Space `x`")
ax.set_ylabel("World Space `y`")
ax.set_xticks([])
ax.set_yticks([])
ax.set_xticklabels([])
ax.set_yticklabels([]);

# %%
quadrants = simple_model.split_up_quadrants((115, 115))

# %%
bottom_right_normalized = quadrants.bottom_right.normalize()
bottom_right_normalized.plot(size=14)
# Out:
# <AxesSubplot:>

# %%
print(bottom_right_normalized.history)
# Out:
# 1. read from blender generated csv at path: /Users/andy/Documents/colby/summer-2022/data-analysis/motra/assets/tracks.csv
# 2. Extracted lower right quadrant of fly model setup
# 3. Normalized Motra Model to Range: [0, 1]

# %%
simple_model.history
# Out:
# '1. read from blender generated csv at path: /Users/andy/Documents/colby/summer-2022/data-analysis/motra/assets/tracks.csv\n'

# %%
scaled = bottom_right_normalized.scale_to_arena_size()

# %%
scaled.plot()
# Out:
# <AxesSubplot:>

# %%
scaled.plot_velocity()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [12], in <cell line: 1>()
# ----> 1 scaled.plot_velocity()
#
# File ~/Documents/colby/summer-2022/data-analysis/motra/motra/motra_model.py:137, in MotraModel.plot_velocity(self, axis, size, apply_legend, x_label, y_label, title, legend_location)
#     134 models = [(identifier, self.retain_only_fly_with_id(identifier)) for identifier in self.get_fly_identifiers()]
#     136 for i, model in models:
# --> 137     axis.plot(model.data[model.dataframe_keys.timestamp], model.velocity,
#     138               label=f"velocity of fly: `{i}`" if apply_legend else None)
#     140 if x_label is not False:
#     141     axis.set_xlabel(x_label if x_label is not None else "Seconds")
#
# File ~/Documents/colby/summer-2022/data-analysis/motra/motra/motra_model.py:255, in MotraModel.velocity(self)
#     253 @property
#     254 def velocity(self):
# --> 255     return self.__velocity.value
#
# File ~/Documents/colby/summer-2022/data-analysis/motra/motra/motra_model.py:80, in Lazy.value(self)
#      74 @property
#      75 def value(self):
#      76     # not sure if this is cheaper in python
#      77     # than a polymorphic call, but I don't
#      78     # care enough to bench that right now.
#      79     if not self.has_value:
# ---> 80         self.__value = self.generation_func()
#      81     return self.__value
#
# File ~/Documents/colby/summer-2022/data-analysis/motra/motra/motra_model.py:313, in MotraModel.__calculate_velocity(self)
#     296 def __calculate_velocity(self) -> np.ndarray:
#     297     # coordinates = self.data[
#     298     #     [self.dataframe_keys.x_pos,
#    (...)
#     311     #     coordinates["pos_x_lagged"], coordinates["pos_y_lagged"]
#     312     # )
# --> 313     return distance(self.get_x_pos(), self.get_y_pos(), self.get_x_pos().shift(1), self.get_x_pos.shift(1))
#
# AttributeError: 'function' object has no attribute 'shift'
